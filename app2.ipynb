# %%
from transformers import AutoTokenizer, AutoModelForQuestionAnswering

model = AutoModelForQuestionAnswering.from_pretrained(
    "ouabdelkrimmina/Arabic-QA-AraBERT"
)
tokenizer = AutoTokenizer.from_pretrained(
    "ouabdelkrimmina/Arabic-QA-AraBERT"
)
